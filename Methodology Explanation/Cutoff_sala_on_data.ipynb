# %%
import pandas as pd
import os
import sys

# Add the path to the directory containing the functions for the analysis.
sys.path.append(r'G:\My Drive\Uni\Thesis\Data\Lab Book\python_functions')

from cutoff_method_sala import cutoff_sala, save_processed_results

# %%
#  Define the directory containing the data files. 
lmcd1_dir = r"G:\My Drive\Uni\Thesis\Data\Lab Book\lmcd1_data"

# Process the data files of LMCD1 and constructs in the specified directory using the cutoff method.
processed_dir = cutoff_sala(lmcd1_dir, LH_column = 'Median(log2(q.ratio))',  venn_save_path=r"G:\My Drive\Uni\Thesis\Data\Lab Book\Resulting Data\Sala_cutoff_data\lmcd1_venns_sala")

# Takes the output from cutoff_sala and saves the resulting dataframes into separate CSV files per construct
save_processed_results(processed_dir, output_dir=r"G:\My Drive\Uni\Thesis\Data\Lab Book\Resulting Data\Sala_cutoff_data\lmcd1_cutoffs_sala")
# Out:
# Processing: Stefano_EXT983_LMCD1_CR
# Venn diagram saved at G:\My Drive\Uni\Thesis\Data\Lab Book\Resulting Data\Sala_cutoff_data\lmcd1_venns_sala\Stefano_EXT983_LMCD1_CR_venn_cutoff.png
# Processing: Stefano_EXT983_LMCD1_FL
# Venn diagram saved at G:\My Drive\Uni\Thesis\Data\Lab Book\Resulting Data\Sala_cutoff_data\lmcd1_venns_sala\Stefano_EXT983_LMCD1_FL_venn_cutoff.png
# Processing: Stefano_EXT983_LMCD1_LIM1-2
# Venn diagram saved at G:\My Drive\Uni\Thesis\Data\Lab Book\Resulting Data\Sala_cutoff_data\lmcd1_venns_sala\Stefano_EXT983_LMCD1_LIM1-2_venn_cutoff.png
# Processing: Stefano_EXT983_LMCD1_PET
# Venn diagram saved at G:\My Drive\Uni\Thesis\Data\Lab Book\Resulting Data\Sala_cutoff_data\lmcd1_venns_sala\Stefano_EXT983_LMCD1_PET_venn_cutoff.png
# Processing: Stefano_EXT983_TES_CRC
# Venn diagram saved at G:\My Drive\Uni\Thesis\Data\Lab Book\Resulting Data\Sala_cutoff_data\lmcd1_venns_sala\Stefano_EXT983_TES_CRC_venn_cutoff.png

# %%
# Perform the same analysis upon the TES data files.
tes_dir = r"G:\My Drive\Uni\Thesis\Data\Lab Book\tes_data"
processed_tes_dir = cutoff_sala(tes_dir, LH_column = 'L/H (log2)', venn_save_path=r"G:\My Drive\Uni\Thesis\Data\Lab Book\Resulting Data\Sala_cutoff_data\tes_venns_sala")
save_processed_results(processed_tes_dir, output_dir=r"G:\My Drive\Uni\Thesis\Data\Lab Book\Resulting Data\Sala_cutoff_data\tes_cutoffs_sala")
# Out:
# Processing: Stefano_ΔPET-GFP
# Venn diagram saved at G:\My Drive\Uni\Thesis\Data\Lab Book\Resulting Data\Sala_cutoff_data\tes_venns_sala\Stefano_ΔPET-GFP_venn_cutoff.png
# Processing: Stefano_FL-GFP
# Venn diagram saved at G:\My Drive\Uni\Thesis\Data\Lab Book\Resulting Data\Sala_cutoff_data\tes_venns_sala\Stefano_FL-GFP_venn_cutoff.png
# Processing: Stefano_PET-GFP
# Venn diagram saved at G:\My Drive\Uni\Thesis\Data\Lab Book\Resulting Data\Sala_cutoff_data\tes_venns_sala\Stefano_PET-GFP_venn_cutoff.png
# Processing: Stefano_NT-GFP
# Venn diagram saved at G:\My Drive\Uni\Thesis\Data\Lab Book\Resulting Data\Sala_cutoff_data\tes_venns_sala\Stefano_NT-GFP_venn_cutoff.png
# Processing: Stefano_LIM1-3-GFP
# Venn diagram saved at G:\My Drive\Uni\Thesis\Data\Lab Book\Resulting Data\Sala_cutoff_data\tes_venns_sala\Stefano_LIM1-3-GFP_venn_cutoff.png
